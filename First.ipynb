# %%
import sys
print("Hello from Python !!")
# Out:
# Hello from Python !!

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\tmitt\Python_Jupyter

# %%
print("VS Code is linked!")
# Out:
# VS Code is linked!
