# %% [markdown]
# # Python
# ## Experiment-1 (Starting With Python)

# %% [markdown]
# 1) Install Python and understand difference between scripting and interactive modes
# in IDLE.
# ![Image](./Images/Installation.png)

# %% [markdown]
# 2) Write Python programs to print strings in the given manner:
# a) Hello Everyone !!!
# b) Hello
#  World
# c) Hello
#  World
# d) ‘ Rohit’ s date of birth is 12\05\1999’

# %%
print("Hello Everyone !!!")
# Out:
# Hello Everyone !!!

# %%
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
print("Hello")
print(" World")
# Out:
# Hello
#  World

# %%
print("' Rohit' s date of birth is 12\\05\\1999'")
# Out:
# ' Rohit' s date of birth is 12\05\1999'

# %% [markdown]
# 3) Declare a string variable called x and assign it the value “Hello”.
#  Print out the value of x

# %%
x = "Hello"
print(x)
# Out:
# Hello

# %% [markdown]
# 4) Take different data types and print values using print function.

# %%
a = 10          # integer
b = 3.14        # float
c = "Python"    # string
d = True        # boolean

print(a)
print(b)
print(c)
print(d)
# Out:
# 10
# 3.14
# Python
# True
