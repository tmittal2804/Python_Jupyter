# %% [markdown]
# -  Name: Tanya Mittal
# -  SAP ID: 590022823
# -  Batch: B17
# -  Course: B. Tech CSE
# -  Subject: Python Programming

# %% [markdown]
# ## Experiment-3: String And Sets

# %% [markdown]
# ### Aim:
